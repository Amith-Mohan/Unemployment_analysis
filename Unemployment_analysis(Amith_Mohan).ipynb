# %% [markdown]
# # Analysis of Unemployment in India During the COVID-19 Pandemic
# Unemployment is typically quantified through the unemployment rate, which represents the percentage of people without jobs in relation to the total labor force. The COVID-19 pandemic led to a substantial upsurge in the unemployment rate.
#
# The objective here is to conduct a Python-based analysis of the unemployment rate in India.
#
# ## Objective:
#
# This analysis is geared towards comprehensively assessing the far-reaching consequences of the COVID-19 pandemic on India's employment landscape. The dataset available offers critical insights into the fluctuations in unemployment rates across different Indian regions. The dataset encompasses vital metrics, including a region-wise breakdown, a timeline of measurements, measurement frequency (monthly), the estimated unemployment rate (%), the count of individuals estimated to be employed, and the estimated labor participation rate (%).
#
# ## Overview of the Dataset:
#
# The provided dataset delves into the unemployment scenario in various Indian regions:
#
# 1. regions: Encompassing the diverse regions of the Indian subcontinent.
# 2. Date: Records the specific dates of unemployment rate measurements.
# 3. Measurement Frequency: Indicates the regularity of data collection, which is on a monthly basis.
# 4. Estimated Unemployment Rate (%): Reflects the percentage of unemployed individuals in each Indian region.
# 5. Estimated Employed Individuals: Represents the count of individuals currently engaged in employment.
# 6. Estimated Labor Participation Rate (%): Demonstrates the percentage of the working-age population (16-64 years) actively participating in the job market, encompassing both employed individuals and those actively seeking employment.
#
# This dataset serves as a valuable resource for understanding the fluctuations in unemployment across different regions in India during the COVID-19 pandemic. By providing crucial insights, it sheds light on the consequences for unemployment rates, employment figures, and labor force participation in distinct geographical regions across the nation. The primary goal of this analysis is to gain insights into the socioeconomic impacts of the pandemic on India's workforce and labor market.

# %%
#Importing required libraries
import requests
import io
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
import calendar 
import plotly.graph_objects as go

# %%
# Importing dataset from GitHub repository

url = "https://raw.githubusercontent.com/Amith-Mohan/datasets/main/Unemployment_in_India.csv" # Raw version of the file on GitHub
download = requests.get(url).content
df = pd.read_csv(io.StringIO(download.decode('utf-8')))

# %%
# Checking first 5 entries
df.head()
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1  Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2  Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3  Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4  Andhra Pradesh   30-09-2019    Monthly                              5.17
#
#     Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 0           11999139.0                                     43.24  Rural
# 1           11755881.0                                     42.05  Rural
# 2           12086707.0                                     43.50  Rural
# 3           12285693.0                                     43.97  Rural
# 4           12256762.0                                     44.68  Rural

# %%
# Checking Last 5 entries
df.tail()
# Out:
#     Region  Date  Frequency   Estimated Unemployment Rate (%)  \
# 763    NaN   NaN        NaN                               NaN
# 764    NaN   NaN        NaN                               NaN
# 765    NaN   NaN        NaN                               NaN
# 766    NaN   NaN        NaN                               NaN
# 767    NaN   NaN        NaN                               NaN
#
#       Estimated Employed   Estimated Labour Participation Rate (%) Area
# 763                  NaN                                       NaN  NaN
# 764                  NaN                                       NaN  NaN
# 765                  NaN                                       NaN  NaN
# 766                  NaN                                       NaN  NaN
# 767                  NaN                                       NaN  NaN

# %%
# Checking datatypes of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 7 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    740 non-null    object
#  1    Date                                     740 non-null    object
#  2    Frequency                                740 non-null    object
#  3    Estimated Unemployment Rate (%)          740 non-null    float64
#  4    Estimated Employed                       740 non-null    float64
#  5    Estimated Labour Participation Rate (%)  740 non-null    float64
#  6   Area                                      740 non-null    object
# dtypes: float64(3), object(4)
# memory usage: 42.1+ KB

# %%
# Null value check
df.isnull().sum()
# Out:
# Region                                      28
#  Date                                       28
#  Frequency                                  28
#  Estimated Unemployment Rate (%)            28
#  Estimated Employed                         28
#  Estimated Labour Participation Rate (%)    28
# Area                                        28
# dtype: int64

# %%
# Dropping rows with null values
df.dropna(inplace=True)

# %%
df.tail()
# Out:
#           Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 749  West Bengal   29-02-2020    Monthly                              7.55
# 750  West Bengal   31-03-2020    Monthly                              6.67
# 751  West Bengal   30-04-2020    Monthly                             15.63
# 752  West Bengal   31-05-2020    Monthly                             15.22
# 753  West Bengal   30-06-2020    Monthly                              9.86
#
#       Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 749           10871168.0                                     44.09  Urban
# 750           10806105.0                                     43.34  Urban
# 751            9299466.0                                     41.20  Urban
# 752            9240903.0                                     40.67  Urban
# 753            9088931.0                                     37.57  Urban

# %%
# Null value check
df.isnull().sum()
# Out:
# Region                                      0
#  Date                                       0
#  Frequency                                  0
#  Estimated Unemployment Rate (%)            0
#  Estimated Employed                         0
#  Estimated Labour Participation Rate (%)    0
# Area                                        0
# dtype: int64

# %% [markdown]
# Null values have been removed from the dataset

# %%
df.columns
# Out:
# Index(['Region', ' Date', ' Frequency', ' Estimated Unemployment Rate (%)',
#        ' Estimated Employed', ' Estimated Labour Participation Rate (%)',
#        'Area'],
#       dtype='object')

# %%
# Renaming column names
df.columns = ['region','date','frequency','estimated_unemployment_rate','estimated_employment','estimated_labour_participation_rate','area']
df.head()
# Out:
#            region         date frequency  estimated_unemployment_rate  \
# 0  Andhra Pradesh   31-05-2019   Monthly                         3.65
# 1  Andhra Pradesh   30-06-2019   Monthly                         3.05
# 2  Andhra Pradesh   31-07-2019   Monthly                         3.75
# 3  Andhra Pradesh   31-08-2019   Monthly                         3.32
# 4  Andhra Pradesh   30-09-2019   Monthly                         5.17
#
#    estimated_employment  estimated_labour_participation_rate   area
# 0            11999139.0                                43.24  Rural
# 1            11755881.0                                42.05  Rural
# 2            12086707.0                                43.50  Rural
# 3            12285693.0                                43.97  Rural
# 4            12256762.0                                44.68  Rural

# %%
# Shape of dataset (rows, columns)
df.shape
# Out:
# (740, 7)

# %%
# Univariate analysis
df.describe()
# Out:
#        estimated_unemployment_rate  estimated_employment  \
# count                   740.000000          7.400000e+02
# mean                     11.787946          7.204460e+06
# std                      10.721298          8.087988e+06
# min                       0.000000          4.942000e+04
# 25%                       4.657500          1.190404e+06
# 50%                       8.350000          4.744178e+06
# 75%                      15.887500          1.127549e+07
# max                      76.740000          4.577751e+07
#
#        estimated_labour_participation_rate
# count                           740.000000
# mean                             42.630122
# std                               8.111094
# min                              13.330000
# 25%                              38.062500
# 50%                              41.160000
# 75%                              45.505000
# max                              72.570000

# %%
# Checking for duplicates in the data 
df.duplicated().any()
# Out:
# False

# %%
# Checking No. of entries for each individual region
df.region.value_counts()
# Out:
# Andhra Pradesh      28
# Kerala              28
# West Bengal         28
# Uttar Pradesh       28
# Tripura             28
# Telangana           28
# Tamil Nadu          28
# Rajasthan           28
# Punjab              28
# Odisha              28
# Madhya Pradesh      28
# Maharashtra         28
# Karnataka           28
# Jharkhand           28
# Himachal Pradesh    28
# Haryana             28
# Gujarat             28
# Delhi               28
# Chhattisgarh        28
# Bihar               28
# Meghalaya           27
# Uttarakhand         27
# Assam               26
# Puducherry          26
# Goa                 24
# Jammu & Kashmir     21
# Sikkim              17
# Chandigarh          12
# Name: region, dtype: int64

# %% [markdown]
# Chandigarh is having the least entries/data

# %%
# Changing datatype of 'date' to datetime format
df['date'] = pd.to_datetime(df['date'],dayfirst = True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 740 entries, 0 to 753
# Data columns (total 7 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   region                               740 non-null    object
#  1   date                                 740 non-null    datetime64[ns]
#  2   frequency                            740 non-null    object
#  3   estimated_unemployment_rate          740 non-null    float64
#  4   estimated_employment                 740 non-null    float64
#  5   estimated_labour_participation_rate  740 non-null    float64
#  6   area                                 740 non-null    object
# dtypes: datetime64[ns](1), float64(3), object(3)
# memory usage: 46.2+ KB

# %% [markdown]
# datatype of 'date' changed to datetime format

# %%
# Extracting month from date
df['month_int'] = df['date'].dt.month
df.head()
# Out:
#            region       date frequency  estimated_unemployment_rate  \
# 0  Andhra Pradesh 2019-05-31   Monthly                         3.65
# 1  Andhra Pradesh 2019-06-30   Monthly                         3.05
# 2  Andhra Pradesh 2019-07-31   Monthly                         3.75
# 3  Andhra Pradesh 2019-08-31   Monthly                         3.32
# 4  Andhra Pradesh 2019-09-30   Monthly                         5.17
#
#    estimated_employment  estimated_labour_participation_rate   area  month_int
# 0            11999139.0                                43.24  Rural          5
# 1            11755881.0                                42.05  Rural          6
# 2            12086707.0                                43.50  Rural          7
# 3            12285693.0                                43.97  Rural          8
# 4            12256762.0                                44.68  Rural          9

# %%
# Converting months into words for better analysis
df['month'] = df['month_int'].apply(lambda x: calendar.month_abbr[x])
df.head()
# Out:
#            region       date frequency  estimated_unemployment_rate  \
# 0  Andhra Pradesh 2019-05-31   Monthly                         3.65
# 1  Andhra Pradesh 2019-06-30   Monthly                         3.05
# 2  Andhra Pradesh 2019-07-31   Monthly                         3.75
# 3  Andhra Pradesh 2019-08-31   Monthly                         3.32
# 4  Andhra Pradesh 2019-09-30   Monthly                         5.17
#
#    estimated_employment  estimated_labour_participation_rate   area  \
# 0            11999139.0                                43.24  Rural
# 1            11755881.0                                42.05  Rural
# 2            12086707.0                                43.50  Rural
# 3            12285693.0                                43.97  Rural
# 4            12256762.0                                44.68  Rural
#
#    month_int month
# 0          5   May
# 1          6   Jun
# 2          7   Jul
# 3          8   Aug
# 4          9   Sep

# %%
# Numeric data grouped by months
data = df.groupby(['month'])[['estimated_unemployment_rate','estimated_employment','estimated_labour_participation_rate']].mean()
data=pd.DataFrame(data).reset_index()
data
# Out:
#    month  estimated_unemployment_rate  estimated_employment  \
# 0    Apr                    23.641569          5.283320e+06
# 1    Aug                     9.637925          7.539815e+06
# 2    Dec                     9.497358          7.377388e+06
# 3    Feb                     9.964717          7.603996e+06
# 4    Jan                     9.950755          7.677344e+06
# 5    Jul                     9.033889          7.404425e+06
# 6    Jun                    10.553462          7.372280e+06
# 7    Mar                    10.700577          7.516581e+06
# 8    May                    16.646190          6.666624e+06
# 9    Nov                     9.868364          7.273661e+06
# 10   Oct                     9.900909          7.298382e+06
# 11   Sep                     9.051731          7.739464e+06
#
#     estimated_labour_participation_rate
# 0                             35.141176
# 1                             43.646792
# 2                             43.667358
# 3                             43.723019
# 4                             44.051321
# 5                             43.706667
# 6                             42.211058
# 7                             43.084038
# 8                             41.277143
# 9                             44.110545
# 10                            44.001273
# 11                            44.301346

# %%
# Bar plot of unemployment rate vs labour participation rate
month = data.month
unemployment_rate = data['estimated_unemployment_rate']
labour_participation_rate = data['estimated_labour_participation_rate']

fig = go.Figure()

fig.add_trace(go.Bar(x = month,y = unemployment_rate,name = 'unemployment_rate'))
fig.add_trace(go.Bar(x = month,y = labour_participation_rate,name = 'estimated_labour_participation_rate'))

fig.update_layout(title = 'Unemployment Rate v/s Labour Participation',
                     xaxis = {'categoryorder':'array','categoryarray':['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']}      )
fig.show()
# Out:
# <div>                            <div id="775513d0-e113-41ac-846e-0f66f622ac9d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("775513d0-e113-41ac-846e-0f66f622ac9d")) {                    Plotly.newPlot(                        "775513d0-e113-41ac-846e-0f66f622ac9d",                        [{"name":"unemployment_rate","x":["Apr","Aug","Dec","Feb","Jan","Jul","Jun","Mar","May","Nov","Oct","Sep"],"y":[23.64156862745098,9.637924528301888,9.497358490566038,9.964716981132076,9.950754716981132,9.033888888888889,10.553461538461537,10.700576923076921,16.646190476190476,9.868363636363636,9.90090909090909,9.051730769230769],"type":"bar"},{"name":"estimated_labour_participation_rate","x":["Apr","Aug","Dec","Feb","Jan","Jul","Jun","Mar","May","Nov","Oct","Sep"],"y":[35.141176470588235,43.64679245283019,43.66735849056604,43.72301886792453,44.05132075471698,43.70666666666666,42.21105769230769,43.08403846153846,41.27714285714286,44.11054545454545,44.00127272727273,44.301346153846154],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outli ...

# %%
# Bar plot of estimated employed citizen in every month
import plotly.express as px
fig = px.bar(data,x='month',y='estimated_employment',color='month',
            category_orders ={'month':['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']},
            title='Estimated employed people from Jan to Dec',template='gridon')
fig.show()
# Out:
# <div>                            <div id="a273e12b-41d2-4d51-9f86-2f81605925b5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a273e12b-41d2-4d51-9f86-2f81605925b5")) {                    Plotly.newPlot(                        "a273e12b-41d2-4d51-9f86-2f81605925b5",                        [{"alignmentgroup":"True","hovertemplate":"month=%{x}<br>estimated_employment=%{y}<extra></extra>","legendgroup":"Jan","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"Jan","offsetgroup":"Jan","orientation":"v","showlegend":true,"textposition":"auto","x":["Jan"],"xaxis":"x","y":[7677344.415094339],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"month=%{x}<br>estimated_employment=%{y}<extra></extra>","legendgroup":"Feb","marker":{"color":"#FF7F0E","pattern":{"shape":""}},"name":"Feb","offsetgroup":"Feb","orientation":"v","showlegend":true,"textposition":"auto","x":["Feb"],"xaxis":"x","y":[7603996.2830188675],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"month=%{x}<br>estimated_employment=%{y}<extra></extra>","legendgroup":"Mar","marker":{"color":"#2CA02C","pattern":{"shape":""}},"name":"Mar","offsetgroup":"Mar","orientation":"v","showlegend":true,"textposition":"auto","x":["Mar"],"xaxis":"x","y":[7516581.134615385],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"month=%{x}<br>estimated_employment=%{y}<extra></extra>","legendgroup":"Apr","marker":{"color":"#D62728","pattern":{"shape":""}},"name":"Apr","offsetgroup":"Apr","orientation":"v","showlegend":true,"textposition":"auto","x":["Apr"],"xaxis":"x","y":[5283319.901960785],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"month=%{x}<br>estimated_employment=%{y}<extra></extra>","legendgroup":"May","marker":{"color":"#9467BD","pattern":{"shape":""}},"name":"May","offsetgroup":"May","orientation":"v","showlegend":true,"textposition":"auto","x":["May"],"xaxis":"x","y":[6666624.095238095],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"month=%{x}<br>estimated_employment=%{y}<extra></extra>","legendgroup":"Jun","marker":{"color":"#8C564B","pattern":{"shape":""}},"name":"Jun","offsetgroup":"Jun","orientation":"v","showlegend":true,"textposition":"auto","x":["Jun"],"xaxis":"x","y":[7372279.596153846],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"month=%{x}<br>estimated_employment=%{y}<extra></extra>","legendgroup":"Jul","marker":{"color":"#E377C2","pattern":{"shape":""}},"name":"Jul","offsetgroup":"Jul","orientation":"v","showlegend":true,"textposition":"auto","x":["Jul"],"xaxis":"x","y":[7404425.314814814],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"month=%{x}<br>estimated_employment=%{y}<extra></extra>","legendgroup":"Aug","marker":{"color":"#7F7F7F","pattern":{"shape":""}},"name":"Aug","offsetgroup":"Aug","orientation":"v","showlegend":true,"textposition":"auto","x":["Aug"],"xaxis":"x","y":[7539815.188679245],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"month=%{x}<br>estimated_employment=%{y}<extra></extra>","legendgroup":"Sep","marker":{"color":"#BCBD22","pattern":{"shape":""}},"name":"Sep","offsetgroup":"Sep","orientation":"v","showlegend":true,"textposition":"auto","x":["Sep"],"xaxis":"x","y":[7739463.961538462],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"month=%{x}<br>estimated_employment=%{y}<extra></extra>","legendgroup":"Oct","marker":{"color":"#17BECF","pattern":{"shape":""}},"name":"Oct","offsetgroup":"Oct","orientation":"v","showlegend":true,"textposition":"auto","x":["Oct"],"xaxis":"x","y":[7298382.4],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"month=%{x}<br>estimated_employment=%{y}<extra></extra>","legendgroup":"Nov","marker" ...
#
# var gd = document.getElementById('a273e12b-41d2-4d51-9f86-2f81605925b5');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                });            </script>        </div>

# %% [markdown]
# # Region Analysis

# %%
region =  df.groupby(['region'])[['estimated_unemployment_rate','estimated_employment','estimated_labour_participation_rate']].mean()
region = pd.DataFrame(region).reset_index()

# %%
# Box plot

fig = px.box(data_frame=df,x='region',y='estimated_unemployment_rate',color='region',title='Unemployment rate',template='gridon')
fig.update_layout(xaxis={'categoryorder':'total ascending'})
fig.show()
# Out:
# <div>                            <div id="39db0900-5774-4012-9005-36b8dd7939e3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("39db0900-5774-4012-9005-36b8dd7939e3")) {                    Plotly.newPlot(                        "39db0900-5774-4012-9005-36b8dd7939e3",                        [{"alignmentgroup":"True","hovertemplate":"region=%{x}<br>estimated_unemployment_rate=%{y}<extra></extra>","legendgroup":"Andhra Pradesh","marker":{"color":"#1F77B4"},"name":"Andhra Pradesh","notched":false,"offsetgroup":"Andhra Pradesh","orientation":"v","showlegend":true,"x":["Andhra Pradesh","Andhra Pradesh","Andhra Pradesh","Andhra Pradesh","Andhra Pradesh","Andhra Pradesh","Andhra Pradesh","Andhra Pradesh","Andhra Pradesh","Andhra Pradesh","Andhra Pradesh","Andhra Pradesh","Andhra Pradesh","Andhra Pradesh","Andhra Pradesh","Andhra Pradesh","Andhra Pradesh","Andhra Pradesh","Andhra Pradesh","Andhra Pradesh","Andhra Pradesh","Andhra Pradesh","Andhra Pradesh","Andhra Pradesh","Andhra Pradesh","Andhra Pradesh","Andhra Pradesh","Andhra Pradesh"],"x0":" ","xaxis":"x","y":[3.65,3.05,3.75,3.32,5.17,3.52,4.12,4.38,4.84,5.91,4.06,16.29,14.46,0.85,6.09,3.8,5.64,4.61,6.01,4.7,7.54,7.88,7.11,5.66,9.88,32.3,24.91,5.86],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"region=%{x}<br>estimated_unemployment_rate=%{y}<extra></extra>","legendgroup":"Assam","marker":{"color":"#FF7F0E"},"name":"Assam","notched":false,"offsetgroup":"Assam","orientation":"v","showlegend":true,"x":["Assam","Assam","Assam","Assam","Assam","Assam","Assam","Assam","Assam","Assam","Assam","Assam","Assam","Assam","Assam","Assam","Assam","Assam","Assam","Assam","Assam","Assam","Assam","Assam","Assam","Assam"],"x0":" ","xaxis":"x","y":[4.29,5.08,4.26,5.79,4.46,4.65,4.66,4.29,3.26,3.77,9.38,0.0,7.87,9.89,3.21,10.39,9.26,11.17,6.31,5.02,7.24,9.98,10.34,8.37,10.77,3.42],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"region=%{x}<br>estimated_unemployment_rate=%{y}<extra></extra>","legendgroup":"Bihar","marker":{"color":"#2CA02C"},"name":"Bihar","notched":false,"offsetgroup":"Bihar","orientation":"v","showlegend":true,"x":["Bihar","Bihar","Bihar","Bihar","Bihar","Bihar","Bihar","Bihar","Bihar","Bihar","Bihar","Bihar","Bihar","Bihar","Bihar","Bihar","Bihar","Bihar","Bihar","Bihar","Bihar","Bihar","Bihar","Bihar","Bihar","Bihar","Bihar","Bihar"],"x0":" ","xaxis":"x","y":[9.27,10.2,13.44,11.0,8.87,12.47,12.4,10.16,9.13,9.61,15.39,45.09,47.26,20.49,19.9,13.29,16.41,17.66,20.46,14.06,17.62,14.91,20.69,15.11,15.73,58.77,37.87,12.45],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"region=%{x}<br>estimated_unemployment_rate=%{y}<extra></extra>","legendgroup":"Chhattisgarh","marker":{"color":"#D62728"},"name":"Chhattisgarh","notched":false,"offsetgroup":"Chhattisgarh","orientation":"v","showlegend":true,"x":["Chhattisgarh","Chhattisgarh","Chhattisgarh","Chhattisgarh","Chhattisgarh","Chhattisgarh","Chhattisgarh","Chhattisgarh","Chhattisgarh","Chhattisgarh","Chhattisgarh","Chhattisgarh","Chhattisgarh","Chhattisgarh","Chhattisgarh","Chhattisgarh","Chhattisgarh","Chhattisgarh","Chhattisgarh","Chhattisgarh","Chhattisgarh","Chhattisgarh","Chhattisgarh","Chhattisgarh","Chhattisgarh","Chhattisgarh","Chhattisgarh","Chhattisgarh"],"x0":" ","xaxis":"x","y":[9.82,6.76,4.54,4.64,8.33,6.96,2.77,6.11,9.89,7.89,7.31,0.0,7.64,10.14,9.77,11.77,8.17,6.29,9.46,10.27,8.32,3.57,9.01,9.79,8.21,20.13,24.1,27.07],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"region=%{x}<br>estimated_unemployment_rate=%{y}<extra></extra>","legendgroup":"Delhi","marker":{"color":"#9467BD"},"name":"Delhi","notched":false,"offsetgroup":"Delhi","orientation":"v","showlegend":true,"x":["Delhi", ...

# %%
# average unemployment rate bar plot

fig = px.bar(region,x='region',y='estimated_unemployment_rate',color='region',template='gridon',title='Average unemployment rate (Region wise)')
fig.update_layout(xaxis={'categoryorder':'total ascending'})
fig.show()
# Out:
# <div>                            <div id="d22b5d29-a683-44a3-8048-a49846f4b501" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d22b5d29-a683-44a3-8048-a49846f4b501")) {                    Plotly.newPlot(                        "d22b5d29-a683-44a3-8048-a49846f4b501",                        [{"alignmentgroup":"True","hovertemplate":"region=%{x}<br>estimated_unemployment_rate=%{y}<extra></extra>","legendgroup":"Andhra Pradesh","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"Andhra Pradesh","offsetgroup":"Andhra Pradesh","orientation":"v","showlegend":true,"textposition":"auto","x":["Andhra Pradesh"],"xaxis":"x","y":[7.477142857142857],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"region=%{x}<br>estimated_unemployment_rate=%{y}<extra></extra>","legendgroup":"Assam","marker":{"color":"#FF7F0E","pattern":{"shape":""}},"name":"Assam","offsetgroup":"Assam","orientation":"v","showlegend":true,"textposition":"auto","x":["Assam"],"xaxis":"x","y":[6.428076923076923],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"region=%{x}<br>estimated_unemployment_rate=%{y}<extra></extra>","legendgroup":"Bihar","marker":{"color":"#2CA02C","pattern":{"shape":""}},"name":"Bihar","offsetgroup":"Bihar","orientation":"v","showlegend":true,"textposition":"auto","x":["Bihar"],"xaxis":"x","y":[18.91821428571429],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"region=%{x}<br>estimated_unemployment_rate=%{y}<extra></extra>","legendgroup":"Chandigarh","marker":{"color":"#D62728","pattern":{"shape":""}},"name":"Chandigarh","offsetgroup":"Chandigarh","orientation":"v","showlegend":true,"textposition":"auto","x":["Chandigarh"],"xaxis":"x","y":[15.991666666666667],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"region=%{x}<br>estimated_unemployment_rate=%{y}<extra></extra>","legendgroup":"Chhattisgarh","marker":{"color":"#9467BD","pattern":{"shape":""}},"name":"Chhattisgarh","offsetgroup":"Chhattisgarh","orientation":"v","showlegend":true,"textposition":"auto","x":["Chhattisgarh"],"xaxis":"x","y":[9.240357142857144],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"region=%{x}<br>estimated_unemployment_rate=%{y}<extra></extra>","legendgroup":"Delhi","marker":{"color":"#8C564B","pattern":{"shape":""}},"name":"Delhi","offsetgroup":"Delhi","orientation":"v","showlegend":true,"textposition":"auto","x":["Delhi"],"xaxis":"x","y":[16.49535714285714],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"region=%{x}<br>estimated_unemployment_rate=%{y}<extra></extra>","legendgroup":"Goa","marker":{"color":"#E377C2","pattern":{"shape":""}},"name":"Goa","offsetgroup":"Goa","orientation":"v","showlegend":true,"textposition":"auto","x":["Goa"],"xaxis":"x","y":[9.274166666666666],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"region=%{x}<br>estimated_unemployment_rate=%{y}<extra></extra>","legendgroup":"Gujarat","marker":{"color":"#7F7F7F","pattern":{"shape":""}},"name":"Gujarat","offsetgroup":"Gujarat","orientation":"v","showlegend":true,"textposition":"auto","x":["Gujarat"],"xaxis":"x","y":[6.663928571428571],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"region=%{x}<br>estimated_unemployment_rate=%{y}<extra></extra>","legendgroup":"Haryana","marker":{"color":"#BCBD22","pattern":{"shape":""}},"name":"Haryana","offsetgroup":"Haryana","orientation":"v","showlegend":true,"textposition":"auto","x":["Haryana"],"xaxis":"x","y":[26.283214285714283],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"region=%{x}<br>estimated_unemployment_rate=%{y}<extra></extra>","legendgroup":"Himachal Pradesh","marker":{"color":"#17BECF","pattern":{"shape":""}},"name":"Himachal Pradesh" ...

# %% [markdown]
# Highest average unemployment can be observed in Tripura and Haryana.
# Lowest average unemployment can be observed in Meghalaya and Odisha

# %%
# Bar plot of monthly Unemployment Rate

fig = px.bar(df,x='region',y='estimated_unemployment_rate',animation_frame='month',color='region',template='gridon',
            title='Unemployment rate from May 2019 to Apr 2020(Region wise)')

fig.update_layout(xaxis={'categoryorder':'total ascending'})
fig.show()
# Out:
# <div>                            <div id="dcb4c8f9-4158-449b-a43c-2d3b5e03bbb3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dcb4c8f9-4158-449b-a43c-2d3b5e03bbb3")) {                    Plotly.newPlot(                        "dcb4c8f9-4158-449b-a43c-2d3b5e03bbb3",                        [{"alignmentgroup":"True","hovertemplate":"region=%{x}<br>month=May<br>estimated_unemployment_rate=%{y}<extra></extra>","legendgroup":"Andhra Pradesh","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"Andhra Pradesh","offsetgroup":"Andhra Pradesh","orientation":"v","showlegend":true,"textposition":"auto","x":["Andhra Pradesh","Andhra Pradesh","Andhra Pradesh","Andhra Pradesh"],"xaxis":"x","y":[3.65,14.46,6.09,24.91],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"region=%{x}<br>month=May<br>estimated_unemployment_rate=%{y}<extra></extra>","legendgroup":"Assam","marker":{"color":"#FF7F0E","pattern":{"shape":""}},"name":"Assam","offsetgroup":"Assam","orientation":"v","showlegend":true,"textposition":"auto","x":["Assam","Assam","Assam","Assam"],"xaxis":"x","y":[4.29,9.38,7.87,10.77],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"region=%{x}<br>month=May<br>estimated_unemployment_rate=%{y}<extra></extra>","legendgroup":"Bihar","marker":{"color":"#2CA02C","pattern":{"shape":""}},"name":"Bihar","offsetgroup":"Bihar","orientation":"v","showlegend":true,"textposition":"auto","x":["Bihar","Bihar","Bihar","Bihar"],"xaxis":"x","y":[9.27,47.26,19.9,37.87],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"region=%{x}<br>month=May<br>estimated_unemployment_rate=%{y}<extra></extra>","legendgroup":"Chhattisgarh","marker":{"color":"#D62728","pattern":{"shape":""}},"name":"Chhattisgarh","offsetgroup":"Chhattisgarh","orientation":"v","showlegend":true,"textposition":"auto","x":["Chhattisgarh","Chhattisgarh","Chhattisgarh","Chhattisgarh"],"xaxis":"x","y":[9.82,7.64,9.77,24.1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"region=%{x}<br>month=May<br>estimated_unemployment_rate=%{y}<extra></extra>","legendgroup":"Delhi","marker":{"color":"#9467BD","pattern":{"shape":""}},"name":"Delhi","offsetgroup":"Delhi","orientation":"v","showlegend":true,"textposition":"auto","x":["Delhi","Delhi","Delhi","Delhi"],"xaxis":"x","y":[12.56,22.76,12.31,45.78],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"region=%{x}<br>month=May<br>estimated_unemployment_rate=%{y}<extra></extra>","legendgroup":"Goa","marker":{"color":"#8C564B","pattern":{"shape":""}},"name":"Goa","offsetgroup":"Goa","orientation":"v","showlegend":true,"textposition":"auto","x":["Goa","Goa","Goa"],"xaxis":"x","y":[2.91,20.0,2.75],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"region=%{x}<br>month=May<br>estimated_unemployment_rate=%{y}<extra></extra>","legendgroup":"Gujarat","marker":{"color":"#E377C2","pattern":{"shape":""}},"name":"Gujarat","offsetgroup":"Gujarat","orientation":"v","showlegend":true,"textposition":"auto","x":["Gujarat","Gujarat","Gujarat","Gujarat"],"xaxis":"x","y":[2.88,14.58,4.09,11.62],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"region=%{x}<br>month=May<br>estimated_unemployment_rate=%{y}<extra></extra>","legendgroup":"Haryana","marker":{"color":"#7F7F7F","pattern":{"shape":""}},"name":"Haryana","offsetgroup":"Haryana","orientation":"v","showlegend":true,"textposition":"auto","x":["Haryana","Haryana","Haryana","Haryana"],"xaxis":"x","y":[14.54,34.22,24.67,38.46],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"region=%{x}<br>month=May<br>estimated_unemployment_rate=%{y}<extra></extra>","legendgroup":"Himachal Pradesh","marker":{"color":"#BCBD22","pattern":{"shape":""}},"name":"Himacha ...

# %% [markdown]
# ## Area Analysis

# %%
df.area.unique()
# Out:
# array(['Rural', 'Urban'], dtype=object)

# %%
# numeric data grouped by region

area = df.groupby(['area'])[['estimated_unemployment_rate','estimated_employment','estimated_labour_participation_rate']].mean()
area = pd.DataFrame(area).reset_index()

# %%
#Scatter plot

fig= px.scatter_matrix(df,dimensions=['estimated_unemployment_rate','estimated_employment','estimated_labour_participation_rate'],color='area',template='gridon')
fig.show()
# Out:
# <div>                            <div id="b9e29934-ac94-4dc1-a31e-02a0e1b1be30" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b9e29934-ac94-4dc1-a31e-02a0e1b1be30")) {                    Plotly.newPlot(                        "b9e29934-ac94-4dc1-a31e-02a0e1b1be30",                        [{"dimensions":[{"axis":{"matches":true},"label":"estimated_unemployment_rate","values":[3.65,3.05,3.75,3.32,5.17,3.52,4.12,4.38,4.84,5.91,4.06,16.29,14.46,0.85,4.29,5.08,4.26,5.79,4.46,4.65,4.66,4.29,3.26,3.77,9.38,0.0,9.27,10.2,13.44,11.0,8.87,12.47,12.4,10.16,9.13,9.61,15.39,45.09,47.26,20.49,9.82,6.76,4.54,4.64,8.33,6.96,2.77,6.11,9.89,7.89,7.31,0.0,7.64,10.14,12.56,9.33,11.07,17.18,12.5,15.84,11.11,16.97,13.48,13.81,15.18,20.69,22.76,21.14,2.91,5.45,10.98,1.98,3.61,7.21,23.71,3.54,5.38,0.0,15.91,20.0,2.88,4.77,4.58,3.7,6.29,4.91,4.68,3.46,5.35,6.64,7.59,12.0,14.58,1.41,14.54,23.08,16.22,30.94,16.36,24.17,16.59,29.56,16.21,27.19,23.92,41.61,34.22,35.57,13.68,11.43,20.59,18.56,15.98,15.81,22.86,19.46,16.67,15.42,17.71,2.13,25.64,1.12,12.78,12.09,13.67,11.32,19.27,14.73,22.19,21.23,16.0,2.22,18.97,7.11,8.46,9.98,12.06,7.12,6.57,8.07,15.15,6.16,9.06,5.01,41.72,55.1,21.53,5.46,5.98,0.52,0.37,3.2,7.13,1.19,0.41,2.57,4.11,2.39,33.17,23.72,10.92,6.63,9.0,4.95,10.32,5.35,9.14,5.0,10.77,4.11,8.91,8.85,10.71,23.38,27.66,3.63,4.25,3.92,4.94,3.08,2.98,2.72,2.94,3.66,4.42,1.19,12.5,22.46,6.46,3.67,4.34,3.66,3.76,4.4,3.81,3.68,3.03,3.8,4.24,5.38,25.28,16.89,9.4,3.16,4.23,1.03,0.52,0.24,3.7,1.5,1.8,0.97,2.76,1.28,8.38,3.73,1.35,4.17,4.71,3.31,3.68,4.31,4.28,4.72,4.67,1.81,3.31,15.09,24.48,9.45,4.59,0.0,0.0,0.0,4.85,0.0,1.18,0.0,1.99,0.58,1.74,2.31,74.51,9.17,12.21,9.64,6.69,8.59,12.56,7.07,6.13,9.69,10.41,10.51,3.69,40.59,20.0,4.03,13.7,9.7,12.5,5.45,14.66,10.47,13.96,8.0,14.48,9.47,12.25,10.45,13.86,5.48,13.11,1.0,0.0,5.81,0.97,0.92,6.01,2.91,1.71,1.46,2.46,3.73,1.18,1.17,6.36,53.19,38.73,2.06,2.23,5.92,2.45,1.4,5.49,7.29,6.47,1.35,5.02,9.02,5.63,4.51,34.01,19.3,29.25,26.64,22.47,25.49,30.23,27.54,25.25,26.53,31.91,26.22,31.61,43.64,14.71,18.84,10.26,11.13,9.19,11.47,6.45,10.18,6.94,8.43,6.06,8.12,9.37,19.92,16.89,8.51,1.63,4.65,5.74,6.11,3.47,4.83,5.56,4.52,4.17,4.85,3.66,3.57,10.71,6.02,5.85,5.62,5.58,5.26,6.78,5.83,5.79,6.79,3.78,7.02,18.32,18.43,4.94]},{"axis":{"matches":true},"label":"estimated_employment","values":[11999139.0,11755881.0,12086707.0,12285693.0,12256762.0,12017412.0,11397681.0,12528395.0,12016676.0,11723617.0,11359660.0,8792827.0,9526902.0,15572975.0,11749334.0,8923222.0,9911534.0,9292039.0,11468349.0,8395906.0,9625362.0,11420996.0,8462814.0,9878742.0,9926176.0,7544937.0,24322330.0,24097712.0,23248875.0,22260203.0,23905700.0,24053140.0,22445989.0,22914530.0,23409006.0,23168192.0,22667882.0,14645275.0,14050319.0,20622566.0,6259019.0,6608626.0,6753622.0,6607694.0,6490776.0,7043840.0,6942931.0,6569385.0,6236201.0,6847173.0,6894808.0,6534321.0,5454091.0,5781095.0,169487.0,149076.0,166605.0,135407.0,166056.0,149511.0,178768.0,145671.0,157791.0,147500.0,152413.0,115487.0,129610.0,112108.0,179340.0,170471.0,167437.0,183603.0,163215.0,177440.0,159489.0,177155.0,158936.0,171672.0,181657.0,128538.0,13954728.0,13199281.0,14327083.0,13507342.0,13280783.0,13828512.0,14487815.0,13877825.0,14301844.0,13973042.0,13483615.0,8587594.0,11121124.0,13243922.0,5249186.0,4745178.0,4826560.0,4558306.0,5127956.0,4798833.0,4875763.0,4603484.0,5062293.0,4570108.0,4366148.0,4041050.0,3914193.0,4357835.0,2045760.0,1957081.0,1916824.0,1969248.0,2039804.0,1946957.0,2024409.0,1922821.0,2041035.0,1952464.0,1800426.0,984171.0,1732050.0,2230075.0,2495186.0,2423742.0,2549316.0,2778624.0,2477621.0,2415724.0,2373488.0,2163397.0,2361004.0,2716966.0,2049617.0,7035766.0,7319782.0,6958404.0,7015356.0,7500122.0,7761243.0,7279628.0,6873437. ...

# %%
df.columns
# Out:
# Index(['region', 'date', 'frequency', 'estimated_unemployment_rate',
#        'estimated_employment', 'estimated_labour_participation_rate', 'area',
#        'month_int', 'month'],
#       dtype='object')

# %%
# Average Unemployment Rate

fig = px.bar(area,x='area',y='estimated_unemployment_rate',color='area',title='Average unemployment rate(Area wise)',template='gridon')
fig.update_layout(xaxis={'categoryorder':'total ascending'})
fig.show()
# Out:
# <div>                            <div id="6a3d3ff5-a456-4aaf-85f9-e9d0a9609712" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6a3d3ff5-a456-4aaf-85f9-e9d0a9609712")) {                    Plotly.newPlot(                        "6a3d3ff5-a456-4aaf-85f9-e9d0a9609712",                        [{"alignmentgroup":"True","hovertemplate":"area=%{x}<br>estimated_unemployment_rate=%{y}<extra></extra>","legendgroup":"Rural","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"Rural","offsetgroup":"Rural","orientation":"v","showlegend":true,"textposition":"auto","x":["Rural"],"xaxis":"x","y":[10.324791086350976],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"area=%{x}<br>estimated_unemployment_rate=%{y}<extra></extra>","legendgroup":"Urban","marker":{"color":"#FF7F0E","pattern":{"shape":""}},"name":"Urban","offsetgroup":"Urban","orientation":"v","showlegend":true,"textposition":"auto","x":["Urban"],"xaxis":"x","y":[13.166614173228345],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"pie":[{"automargin":true,"type":"pie"}]},"layout":{"xaxis":{"showgrid":true,"title":{"standoff":15}},"yaxis":{"showgrid":true,"title":{"standoff":15}}}},"xaxis":{"anchor":"y","domain":[0.0,1.0],"title":{"text":"area"},"categoryorder":"total ascending","categoryarray":["Rural","Urban"]},"yaxis":{"anchor":"x","domain":[0.0,1.0],"title":{"text":"estimated_unemployment_rate"}},"legend":{"title":{"text":"area"},"tracegroupgap":0},"title":{"text":"Average unemployment rate(Area wise)"},"barmode":"relative"},                        {"responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('6a3d3ff5-a456-4aaf-85f9-e9d0a9609712');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                });            </script>        </div>

# %% [markdown]
# Unemployment seems to be higher in Urban area as compared to Rural area.

# %%
fig = px.bar(df,x='area',y='estimated_unemployment_rate',animation_frame='month',color='region',
            title='Unemployment rate from May 2019 to Apr 2020',template='gridon')

fig.update_layout(xaxis={'categoryorder':'total ascending'})
fig.layout.updatemenus[0].buttons[0].args[1]['frame']['duration'] =2000

fig.show()
# Out:
# <div>                            <div id="eca4e870-9bb9-4b8e-a0ff-bde91d9f2c51" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("eca4e870-9bb9-4b8e-a0ff-bde91d9f2c51")) {                    Plotly.newPlot(                        "eca4e870-9bb9-4b8e-a0ff-bde91d9f2c51",                        [{"alignmentgroup":"True","hovertemplate":"region=Andhra Pradesh<br>month=May<br>area=%{x}<br>estimated_unemployment_rate=%{y}<extra></extra>","legendgroup":"Andhra Pradesh","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"Andhra Pradesh","offsetgroup":"Andhra Pradesh","orientation":"v","showlegend":true,"textposition":"auto","x":["Rural","Rural","Urban","Urban"],"xaxis":"x","y":[3.65,14.46,6.09,24.91],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"region=Assam<br>month=May<br>area=%{x}<br>estimated_unemployment_rate=%{y}<extra></extra>","legendgroup":"Assam","marker":{"color":"#FF7F0E","pattern":{"shape":""}},"name":"Assam","offsetgroup":"Assam","orientation":"v","showlegend":true,"textposition":"auto","x":["Rural","Rural","Urban","Urban"],"xaxis":"x","y":[4.29,9.38,7.87,10.77],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"region=Bihar<br>month=May<br>area=%{x}<br>estimated_unemployment_rate=%{y}<extra></extra>","legendgroup":"Bihar","marker":{"color":"#2CA02C","pattern":{"shape":""}},"name":"Bihar","offsetgroup":"Bihar","orientation":"v","showlegend":true,"textposition":"auto","x":["Rural","Rural","Urban","Urban"],"xaxis":"x","y":[9.27,47.26,19.9,37.87],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"region=Chhattisgarh<br>month=May<br>area=%{x}<br>estimated_unemployment_rate=%{y}<extra></extra>","legendgroup":"Chhattisgarh","marker":{"color":"#D62728","pattern":{"shape":""}},"name":"Chhattisgarh","offsetgroup":"Chhattisgarh","orientation":"v","showlegend":true,"textposition":"auto","x":["Rural","Rural","Urban","Urban"],"xaxis":"x","y":[9.82,7.64,9.77,24.1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"region=Delhi<br>month=May<br>area=%{x}<br>estimated_unemployment_rate=%{y}<extra></extra>","legendgroup":"Delhi","marker":{"color":"#9467BD","pattern":{"shape":""}},"name":"Delhi","offsetgroup":"Delhi","orientation":"v","showlegend":true,"textposition":"auto","x":["Rural","Rural","Urban","Urban"],"xaxis":"x","y":[12.56,22.76,12.31,45.78],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"region=Goa<br>month=May<br>area=%{x}<br>estimated_unemployment_rate=%{y}<extra></extra>","legendgroup":"Goa","marker":{"color":"#8C564B","pattern":{"shape":""}},"name":"Goa","offsetgroup":"Goa","orientation":"v","showlegend":true,"textposition":"auto","x":["Rural","Rural","Urban"],"xaxis":"x","y":[2.91,20.0,2.75],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"region=Gujarat<br>month=May<br>area=%{x}<br>estimated_unemployment_rate=%{y}<extra></extra>","legendgroup":"Gujarat","marker":{"color":"#E377C2","pattern":{"shape":""}},"name":"Gujarat","offsetgroup":"Gujarat","orientation":"v","showlegend":true,"textposition":"auto","x":["Rural","Rural","Urban","Urban"],"xaxis":"x","y":[2.88,14.58,4.09,11.62],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"region=Haryana<br>month=May<br>area=%{x}<br>estimated_unemployment_rate=%{y}<extra></extra>","legendgroup":"Haryana","marker":{"color":"#7F7F7F","pattern":{"shape":""}},"name":"Haryana","offsetgroup":"Haryana","orientation":"v","showlegend":true,"textposition":"auto","x":["Rural","Rural","Urban","Urban"],"xaxis":"x","y":[14.54,34.22,24.67,38.46],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"region=Himachal Pradesh<br>month=May<br>area=%{x}<br>estimated_unemployment_rate=%{y}<extra></extra>","legendgroup":"Hima ...

# %%
unemployment =df.groupby(['area','region'])['estimated_unemployment_rate'].mean().reset_index()
unemployment.head()
# Out:
#     area          region  estimated_unemployment_rate
# 0  Rural  Andhra Pradesh                     5.526429
# 1  Rural           Assam                     4.490833
# 2  Rural           Bihar                    16.770000
# 3  Rural    Chhattisgarh                     6.628571
# 4  Rural           Delhi                    15.258571

# %%
fig = px.sunburst(unemployment,path=['area','region'],values='estimated_unemployment_rate',
                 title ='Unemployment rate in area and region',height=750,template='gridon')
fig.show()
# Out:
# <div>                            <div id="ab2911ad-6856-434b-8188-98df351b6c2f" class="plotly-graph-div" style="height:750px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ab2911ad-6856-434b-8188-98df351b6c2f")) {                    Plotly.newPlot(                        "ab2911ad-6856-434b-8188-98df351b6c2f",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>estimated_unemployment_rate=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["Rural/Andhra Pradesh","Urban/Andhra Pradesh","Rural/Assam","Urban/Assam","Rural/Bihar","Urban/Bihar","Urban/Chandigarh","Rural/Chhattisgarh","Urban/Chhattisgarh","Rural/Delhi","Urban/Delhi","Rural/Goa","Urban/Goa","Rural/Gujarat","Urban/Gujarat","Rural/Haryana","Urban/Haryana","Rural/Himachal Pradesh","Urban/Himachal Pradesh","Rural/Jammu & Kashmir","Urban/Jammu & Kashmir","Rural/Jharkhand","Urban/Jharkhand","Rural/Karnataka","Urban/Karnataka","Rural/Kerala","Urban/Kerala","Rural/Madhya Pradesh","Urban/Madhya Pradesh","Rural/Maharashtra","Urban/Maharashtra","Rural/Meghalaya","Urban/Meghalaya","Rural/Odisha","Urban/Odisha","Rural/Puducherry","Urban/Puducherry","Rural/Punjab","Urban/Punjab","Rural/Rajasthan","Urban/Rajasthan","Rural/Sikkim","Urban/Sikkim","Rural/Tamil Nadu","Urban/Tamil Nadu","Rural/Telangana","Urban/Telangana","Rural/Tripura","Urban/Tripura","Rural/Uttar Pradesh","Urban/Uttar Pradesh","Rural/Uttarakhand","Urban/Uttarakhand","Rural/West Bengal","Urban/West Bengal","Rural","Urban"],"labels":["Andhra Pradesh","Andhra Pradesh","Assam","Assam","Bihar","Bihar","Chandigarh","Chhattisgarh","Chhattisgarh","Delhi","Delhi","Goa","Goa","Gujarat","Gujarat","Haryana","Haryana","Himachal Pradesh","Himachal Pradesh","Jammu & Kashmir","Jammu & Kashmir","Jharkhand","Jharkhand","Karnataka","Karnataka","Kerala","Kerala","Madhya Pradesh","Madhya Pradesh","Maharashtra","Maharashtra","Meghalaya","Meghalaya","Odisha","Odisha","Puducherry","Puducherry","Punjab","Punjab","Rajasthan","Rajasthan","Sikkim","Sikkim","Tamil Nadu","Tamil Nadu","Telangana","Telangana","Tripura","Tripura","Uttar Pradesh","Uttar Pradesh","Uttarakhand","Uttarakhand","West Bengal","West Bengal","Rural","Urban"],"name":"","parents":["Rural","Urban","Rural","Urban","Rural","Urban","Urban","Rural","Urban","Rural","Urban","Rural","Urban","Rural","Urban","Rural","Urban","Rural","Urban","Rural","Urban","Rural","Urban","Rural","Urban","Rural","Urban","Rural","Urban","Rural","Urban","Rural","Urban","Rural","Urban","Rural","Urban","Rural","Urban","Rural","Urban","Rural","Urban","Rural","Urban","Rural","Urban","Rural","Urban","Rural","Urban","Rural","Urban","Rural","Urban","",""],"values":[5.526428571428572,9.427857142857144,4.490833333333334,8.088571428571429,16.77,21.06642857142857,15.991666666666667,6.628571428571428,11.852142857142857,15.258571428571429,17.732142857142858,8.39,10.158333333333333,5.917142857142857,7.410714285714286,25.012857142857143,27.553571428571427,15.504285714285714,21.576428571428572,14.951818181818181,17.549,15.221428571428572,25.94857142857143,7.224285714285714,6.127857142857144,10.34142857142857,9.906428571428572,5.653571428571429,9.159285714285716,6.8100000000000005,8.305,2.4750000000000005,7.3015384615384615,6.612857142857143,4.702857142857143,7.263333333333333,12.745000000000001,11.924999999999999,12.137142857142859,10.927142857142856,17.189285714285713,5.08,8.153333333333334,8.775714285714285,9.792857142857143,7.863571428571428,7.6121428571428575,27.166428571428572,29.534285714285716,10.20857142857143,14.894285714285715,4.882307692307692,8.162142857142857,7.5721428571428575,8.677142857142858,274.4532925407925,368.75601465201464],"type":"sunburst"}],                        {"template":{"data":{"pie":[{"automargin":true,"type":"pie"}] ...
#
# var gd = document.getElementById('ab2911ad-6856-434b-8188-98df351b6c2f');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                });            </script>        </div>

# %% [markdown]
# ## Unemployment rate before and after Lockdown

# %%
# data representation before and after lockdown
before_lockdown = df[(df['month_int']>=1) &(df['month_int'] <4)]
after_lockdown = df[(df['month_int'] >=4) & (df['month_int'] <=6)]

# %%
af_lockdown = after_lockdown.groupby('region')['estimated_unemployment_rate'].mean().reset_index()
lockdown = before_lockdown.groupby('region')['estimated_unemployment_rate'].mean().reset_index()
lockdown['unemployment rate before lockdown'] = af_lockdown['estimated_unemployment_rate']
lockdown.columns = ['Region','Unemployment_rate_before_lockdown','Unemployment_rate_after_lockdown']
lockdown
# Out:
#               Region  Unemployment_rate_before_lockdown  \
# 0     Andhra Pradesh                           6.243333
# 1              Assam                           6.480000
# 2              Bihar                          14.276667
# 3         Chandigarh                          19.366667
# 4       Chhattisgarh                           8.683333
# 5              Delhi                          16.145000
# 6                Goa                           5.074000
# 7            Gujarat                           6.138333
# 8            Haryana                          24.165000
# 9   Himachal Pradesh                          20.283333
# 10   Jammu & Kashmir                          18.685000
# 11         Jharkhand                          13.210000
# 12         Karnataka                           3.363333
# 13            Kerala                           7.290000
# 14    Madhya Pradesh                           4.033333
# 15       Maharashtra                           5.295000
# 16         Meghalaya                           3.323333
# 17            Odisha                           4.773333
# 18        Puducherry                           1.266667
# 19            Punjab                          11.041667
# 20         Rajasthan                          14.388333
# 21            Sikkim                          20.450000
# 22        Tamil Nadu                           3.421667
# 23         Telangana                           6.500000
# 24           Tripura                          30.613333
# 25     Uttar Pradesh                           9.976667
# 26       Uttarakhand                           6.274000
# 27       West Bengal                           6.513333
#
#     Unemployment_rate_after_lockdown
# 0                          11.126000
# 1                           6.563333
# 2                          27.459000
# 3                          12.656667
# 4                          12.720000
# 5                          19.195000
# 6                          10.301429
# 7                           8.814000
# 8                          30.887000
# 9                          14.982000
# 10                         14.562857
# 11                         32.269000
# 12                         13.793000
# 13                         15.404000
# 14                         12.474000
# 15                         11.304000
# 16                          7.764444
# 17                          8.566000
# 18                         29.006250
# 19                         14.454000
# 20                         15.619000
# 21                          7.131429
# 22                         19.475000
# 23                         12.291000
# 24                         27.249000
# 25                         16.478000
# 26                          7.370000
# 27                         10.890000

# %% [markdown]
# Unemployment rate has significantly gone up after the lockdown

# %%
# Change in unemployment rate after lockdown
lockdown['rate change in unemployment'] =round(lockdown['Unemployment_rate_after_lockdown']-lockdown['Unemployment_rate_before_lockdown']
                                              /lockdown['Unemployment_rate_before_lockdown'],2)

# %%
fig = px.bar(lockdown,x='Region',y='rate change in unemployment',color='rate change in unemployment',
            title='Percentage change in Unemployment rate in each region after lockdown',template='gridon')
fig.update_layout(xaxis={'categoryorder':'total ascending'})
fig.show()
# Out:
# <div>                            <div id="3f2c19f0-c26c-4da7-a950-faa0b31467e6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3f2c19f0-c26c-4da7-a950-faa0b31467e6")) {                    Plotly.newPlot(                        "3f2c19f0-c26c-4da7-a950-faa0b31467e6",                        [{"alignmentgroup":"True","hovertemplate":"Region=%{x}<br>rate change in unemployment=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[10.13,5.56,26.46,11.66,11.72,18.2,9.3,7.81,29.89,13.98,13.56,31.27,12.79,14.4,11.47,10.3,6.76,7.57,28.01,13.45,14.62,6.13,18.48,11.29,26.25,15.48,6.37,9.89],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Andhra Pradesh","Assam","Bihar","Chandigarh","Chhattisgarh","Delhi","Goa","Gujarat","Haryana","Himachal Pradesh","Jammu & Kashmir","Jharkhand","Karnataka","Kerala","Madhya Pradesh","Maharashtra","Meghalaya","Odisha","Puducherry","Punjab","Rajasthan","Sikkim","Tamil Nadu","Telangana","Tripura","Uttar Pradesh","Uttarakhand","West Bengal"],"xaxis":"x","y":[10.13,5.56,26.46,11.66,11.72,18.2,9.3,7.81,29.89,13.98,13.56,31.27,12.79,14.4,11.47,10.3,6.76,7.57,28.01,13.45,14.62,6.13,18.48,11.29,26.25,15.48,6.37,9.89],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"pie":[{"automargin":true,"type":"pie"}]},"layout":{"xaxis":{"showgrid":true,"title":{"standoff":15}},"yaxis":{"showgrid":true,"title":{"standoff":15}}}},"xaxis":{"anchor":"y","domain":[0.0,1.0],"title":{"text":"Region"},"categoryorder":"total ascending"},"yaxis":{"anchor":"x","domain":[0.0,1.0],"title":{"text":"rate change in unemployment"}},"coloraxis":{"colorbar":{"title":{"text":"rate change in unemployment"}},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]},"legend":{"tracegroupgap":0},"title":{"text":"Percentage change in Unemployment rate in each region after lockdown"},"barmode":"relative"},                        {"responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('3f2c19f0-c26c-4da7-a950-faa0b31467e6');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                });            </script>        </div>

# %% [markdown]
# As per the data, Post lockdown:
# Highest percentage change in unemployment rate can be observed in Jharkhand and Haryana
# Lowest percentage change in unemployment rate can be observed in Assam and Sikkim
